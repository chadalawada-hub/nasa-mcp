# %%
from dotenv import load_dotenv
import os

# Load .env from parent directory
load_dotenv(dotenv_path="../.env")

# Set the environment variable so nasa.py can access it
print(f"API Key loaded: {os.getenv('NASA_API_KEY')[:10]}..." if os.getenv('NASA_API_KEY') else "API Key NOT found")
# Out:
# API Key loaded: KICxMkpXfV...

# %%
from nasa import get_nasa_apod, search_nasa_images

apod = get_nasa_apod(date="2026-01-09")
apod
# Out:
# {'copyright': 'ice halos',
#  'date': '2026-01-09',
#  'explanation': "Both Moon and Sun create beautiful ice halos in planet Earth's sky. In fact, the two brightest celestial beacons are each surrounded by a complex of ice halos in these photos of the sky above Chamonix-Mont-Blanc in France. The panels were recorded one night (left) and the following day at the end of December 2025. Similar ice halos appear in moonlight and sunlight because they are all formed through the geometry of flat, hexagonal ice crystals. The ice crystals reflect and refract light as they flutter in the cold atmosphere above the mountain resort. In the pictures both Moon and Sun are surrounded by a more commonly seen 22 degree circular halo. Bright and sometimes colorful patches at the intersections of the 22 degree circular halos with the indicated parselenic and parhelic arcs are also known as Moon dogs and Sun dogs. (Editor's note: Annotations updated by Marcella Pace)",
# ...

# %%
saturn = search_nasa_images(query='saturn hexagon', size=3)
saturn
# Out:
# {'collection': {'version': '1.1',
#   'href': 'http://images-api.nasa.gov/search?q=saturn+hexagon&media_type=image&page=1&page_size=3',
#   'items': [{'href': 'https://images-assets.nasa.gov/image/PIA10217/collection.json',
#     'data': [{'center': 'JPL',
#       'date_created': '2008-01-07T16:18:53Z',
#       'description': 'Saturn North Pole Hot Spot and Hexagon',
#       'description_508': 'Saturn North Pole Hot Spot and Hexagon',
#       'keywords': ['Saturn', 'Cassini-Huygens'],
#       'media_type': 'image',
#       'nasa_id': 'PIA10217',
#       'secondary_creator': 'NASA/JPL/GSFC/Oxford University',
#       'title': 'Saturn North Pole Hot Spot and Hexagon'}],
#     'links': [{'href': 'https://images-assets.nasa.gov/image/PIA10217/PIA10217~thumb.jpg',
#       'rel': 'preview',
#       'render': 'image',
#       'width': 306,
#       'size': 15000,
#       'height': 293},
#      {'href': 'https://images-assets.nasa.gov/image/PIA10217/PIA10217~orig.jpg',
# ...
